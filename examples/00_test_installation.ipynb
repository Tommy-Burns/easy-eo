# %% [markdown]
# ## Testing successful installation of easy-eo

# %%
import eeo
import rasterio
import geopandas
import numpy
import matplotlib

print("Easy-EO version:", eeo.__version__)
print("Rasterio version:", rasterio.__version__)
print("GeoPandas version:", geopandas.__version__)
print("Numpy version:", numpy.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Easy-EO installed")
# Out:
# Easy-EO version: 0.1.0
# Rasterio version: 1.4.4
# GeoPandas version: 1.1.2
# Numpy version: 2.1.3
# Matplotlib version: 3.10.8
# Easy-EO installed
